# %% [markdown]
# <a href="https://colab.research.google.com/github/miguelsarvia/PrograIII-Semi-2026/blob/main/miPrimerProyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
saludo = "Hola Chicos de progra III"
print(saludo,"Primera letra del saludo", saludo[0:4])

num1 = 5.25
print (num1)

booleano = True
print(booleano)
# Out:
# Hola Chicos de progra III Primera letra del saludo Hola
# 5.25
# True

# %%
print ("Sumar dos numeros:")
num1 = input("num 1:")
num2 = input("num 2:")
respuesta = float(num1) + float(num2)

print (type(num1),type(num2),type(respuesta))

print("Respuesta", respuesta)
respuesta = "SUMA COPMPLETA"
print(respuesta,type(respuesta))
# Out:
# Sumar dos numeros:
# num 1:4
# num 2:4
# <class 'str'> <class 'str'> <class 'float'>
# Respuesta 8.0
# SUMA COPMPLETA <class 'str'>

# %%
print ("Reste dos numeros:")
num1 = input("num 1:")
num2 = input("num 2:")
respuesta = float(num1) - float(num2)

print (type(num1),type(num2),type(respuesta))

print("Respuesta", respuesta)
respuesta = "RESTA COPMPLETA"
print(respuesta,type(respuesta))
# Out:
# Reste dos numeros:
# num 1:5
# num 2:4
# <class 'str'> <class 'str'> <class 'float'>
# Respuesta 1.0
# RESTA COPMPLETA <class 'str'>

# %%
print ("Mltiplicar dos numeros:")
num1 = input("num 1:")
num2 = input("num 2:")
respuesta = float(num1) * float(num2)

print (type(num1),type(num2),type(respuesta))

print("Respuesta", respuesta)
respuesta = "MULTIPLICACION COMPLETA"
print(respuesta,type(respuesta))
# Out:
# Mltiplicar dos numeros:
# num 1:5
# num 2:5
# <class 'str'> <class 'str'> <class 'float'>
# Respuesta 25.0
# MULTIPLICACION COMPLETA <class 'str'>

# %%
print ("division dos numeros:")
num1 = input("num 1:")
num2 = input("num 2:")
respuesta = float(num1) / float(num2)

print (type(num1),type(num2),type(respuesta))

print("Respuesta", respuesta)
respuesta = "DIVISION COPMPLETA"
print(respuesta,type(respuesta))
# Out:
# division dos numeros:
# num 1:25
# num 2:5
# <class 'str'> <class 'str'> <class 'float'>
# Respuesta 5.0
# DIVISION COPMPLETA <class 'str'>
